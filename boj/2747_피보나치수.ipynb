# %% [markdown]
# ![image.png](attachment:603b324e-e30c-4e96-821d-3ceb22c40a0a.png)

# %%
import sys
import time
start_time = time.time()

n = int(input())

dp = [0] * (n+1)
dp[1] = 1

for i in range(2, n+1):
    dp[i] = dp[i-2] + dp[i-1]

print(dp[n])

end_time = time.time()
print("time:", end_time-start_time)
# Out:
#  30
# 832040
# time: 3.0363426208496094
