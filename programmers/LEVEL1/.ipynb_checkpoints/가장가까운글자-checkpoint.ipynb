# %% [markdown]
# ![image.png](attachment:9df27162-44cf-4608-9c2b-d360947b8055.png)

# %% [markdown]
# |s|result|
# |:---|:---|
# |"banana"|[-1, -1, -1, 2, 2, 2]|
# |"foobar"|[-1, -1, 1, -1, -1, -1]|

# %%
def solution(s):
    answer = []
    return answer

# %%
# 2시 17분 완료
s = 'foobar'

s_list = list(reversed(list(s)))

s_rslt = [-1] * len(s_list)

for idx, item in enumerate(s_list):
    for y in range(idx+1, len(s_list)):
        if item == s_list[y]:
            s_rslt[idx] = y-idx
            break
list(reversed(list(s_rslt)))
# Out:
# [-1, -1, 1, -1, -1, -1]
