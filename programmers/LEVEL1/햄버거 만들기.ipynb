# %% [markdown]
# ![image.png](attachment:09d464f8-8519-4b52-a93f-9539edfdf6aa.png)

# %%
def solution(ingredient):
    answer = 0
    return answer

# %%
ingredient =  [1, 2, 3, 1, 2, 3, 1, 1, 1, 1, 2, 3, 1, 2, 3, 1, 1, 1, 1, 1, 1, 2, 3, 3, 1, 2, 3, 1, 3, 3, 3, 2, 1, 2, 3, 1]
rslt_cnt = 0
cnt= 0
while True:
    con_flag = False
    for idx in range(len(ingredient)):
        if idx+3 < len(ingredient):
            if ingredient[idx] == 1 and ingredient[idx+1] == 2 and ingredient[idx+2] == 3 and ingredient[idx+3] == 1:
                ingredient.pop(idx)
                ingredient.pop(idx)
                ingredient.pop(idx)
                ingredient.pop(idx)
                rslt_cnt+=1
                con_flag = True
                #break는 for문을 더 돌게한다...
                #break
    if con_flag == False:
        break
        
print(rslt_cnt)
# Out:
# 5

# %%
ingredient =  [1, 2, 3, 1, 2, 3, 1, 1, 1, 1, 2, 3, 1, 2, 3, 1, 1, 1, 1, 1, 1, 2, 3, 3, 1, 2, 3, 1, 3, 3, 3, 2, 1, 2, 3, 1]

rslt = 0
tray = []

for item in ingredient:
    tray.append(item)

    if tray[-4:] == [1,2,3,1]:
        del tray[-4:]
        rslt+=1
print(rslt)
# Out:
# 5
